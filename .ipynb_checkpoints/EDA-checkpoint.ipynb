# %%
import pandas as pd
rep = pd.read_excel('CONST_REP_Northwestern.xlsx')
# Out:
# /Users/Cecilia/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
import copy
data = copy.deepcopy(rep)
data.head()
# Out:
#   Key_Indicator       ID Deceased         Constituency Code         ZIP  \
# 0             O  1256354       No      Business/Corporation       60601
# 1             I  1256355       No                Individual  60189-7519
# 2             I  1256356       No                Individual  60192-1864
# 3             O  1256357       No  Organization/Institution  60011-0803
# 4             I  1264564       No                Individual       60047
#
#   First Gift Date  First Gift Amount First Gift Appeal_ID  \
# 0      2013-02-20              500.0               PCFY13
# 1      2013-02-20              100.0           UNSLTRIB13
# 2      2013-02-20                1.0            UNSLDON13
# 3      2013-06-30             4000.0         FOUNDGRANT13
# 4      2017-03-06                1.0            UNSLDON17
#
#       First Gift Appeal Description   Solicit Code1 Solicit Code2  \
# 0   Poker Tournament & Casino Night             NaN           NaN
# ...

# %%
## group by appeal? campaign?
